# %% [markdown]
# ## understanding `append`

# %%
# start fresh with new groups
jackson5 = ['jackie', 'tito', 'jermaine', 'marlon', 'michael']
destiny  = ['beyonce', 'kelly', 'michelle']
top40    = ['taylorswift', 'postmalone']

# %% [markdown]
# ## looping over a list

# %%
# loop over 'destiny'
for item in destiny:
    print(item)
# Out:
# beyonce
# kelly
# michelle

# %% [markdown]
# ## executing a nested `for` loop

# %%
# loop within a loop
for item in destiny:
    for i in range(len(item)):
        print(item[i])
# Out:
# b
# e
# y
# o
# n
# c
# e
# k
# e
# l
# l
# y
# m
# i
# c
# h
# e
# l
# l
# e

# %% [markdown]
# ### retrieve the index _and_ the value with `enumerate()`

# %%
# lots of flexibility with enumerate()
presidents = ["George Washington", "John Adams", "Thomas Jefferson", "James Madison", "James Monroe", "John Quincy Adams", "Andrew Jackson", "Martin Van Buren", "William Henry Harrison", "John Tyler", "James Knox Polk", "Zachary Taylor", "Millard Fillmore", "Franklin Pierce", "James Buchanan", "Abraham Lincoln", "Andrew Johnson", "Ulysses S. Grant", "Rutherford Birchard Hayes", "James Abram Garfield", "Chester Alan Arthur", "Grover Cleveland", "Benjamin Harrison", "Grover Cleveland", "William McKinley", "Theodore Roosevelt", "William Howard Taft", "Woodrow Wilson", "Warren Gamaliel Harding", "Calvin Coolidge", "Herbert Clark Hoover", "Franklin Delano Roosevelt", "Harry S. Truman", "Dwight David Eisenhower", "John Fitzgerald Kennedy", "Lyndon Baines Johnson", "Richard Milhous Nixon", "Gerald Rudolph Ford", "James Earl Carter Jr.", "Ronald Wilson Reagan", "George Herbert Walker Bush", "William Jefferson Clinton", "George Walker Bush", "Barack Hussein Obama", "Donald Trump", "Joe Biden"]

for index,value in enumerate(presidents):
    print(f"President {index}: {value}")
# Out:
# President 0: George Washington
# President 1: John Adams
# President 2: Thomas Jefferson
# President 3: James Madison
# President 4: James Monroe
# President 5: John Quincy Adams
# President 6: Andrew Jackson
# President 7: Martin Van Buren
# President 8: William Henry Harrison
# President 9: John Tyler
# President 10: James Knox Polk
# President 11: Zachary Taylor
# President 12: Millard Fillmore
# President 13: Franklin Pierce
# President 14: James Buchanan
# President 15: Abraham Lincoln
# President 16: Andrew Johnson
# President 17: Ulysses S. Grant
# President 18: Rutherford Birchard Hayes
# President 19: James Abram Garfield
# President 20: Chester Alan Arthur
# President 21: Grover Cleveland
# President 22: Benjamin Harrison
# President 23: Grover Cleveland
# President 24: William McKinley
# President 25: Theodore Roosevelt
# President 26: William Howard Taft
# President 27: Woodrow Wilson
# President 28: Warren Gamaliel Harding
# President 29: Calvin Coolidge
# President 30: Herbert Clark Hoover
# President 31: Franklin Delano Roosevelt
# President 32: Harry S. Truman
# President 33: Dwight David Eisenhower
# President 34: John Fitzgerald Kennedy
# President 35: Lyndon Baines Johnson
# President 36: Richard Milhous Nixon
# President 37: Gerald Rudolph Ford
# President 38: James Earl Carter Jr.
# President 39: Ronald Wilson Reagan
# President 40: George Herbert Walker Bush
# President 41: William Jefferson Clinton
# President 42: George Walker Bush
# President 43: Barack Hussein Obama
# President 44: Donald Trump
# President 45: Joe Biden

# %% [markdown]
# ## loop over a string

# %%
today = "Wednesday"

for i,letter in enumerate(today):
    print(f'Letter #{i+1}: {letter}')
# Out:
# Letter #1: W
# Letter #2: e
# Letter #3: d
# Letter #4: n
# Letter #5: e
# Letter #6: s
# Letter #7: d
# Letter #8: a
# Letter #9: y
